# %%
import pandas as pd

url = "https://archive.ics.uci.edu/static/public/350/data.csv"
data = pd.read_csv(url, sep= ',')
print(data.head())
# Out:
#    ID      X1  X2  X3  X4  X5  X6  X7  X8  X9  ...    X15    X16    X17   X18  \
# 0   1   20000   2   2   1  24   2   2  -1  -1  ...      0      0      0     0
# 1   2  120000   2   2   2  26  -1   2   0   0  ...   3272   3455   3261     0
# 2   3   90000   2   2   2  34   0   0   0   0  ...  14331  14948  15549  1518
# 3   4   50000   2   2   1  37   0   0   0   0  ...  28314  28959  29547  2000
# 4   5   50000   1   2   1  57  -1   0  -1   0  ...  20940  19146  19131  2000
#
#      X19    X20   X21   X22   X23  Y
# 0    689      0     0     0     0  1
# 1   1000   1000  1000     0  2000  1
# 2   1500   1000  1000  1000  5000  0
# 3   2019   1200  1100  1069  1000  0
# 4  36681  10000  9000   689   679  0
#
# [5 rows x 25 columns]

# %%
data.rename(columns={'X1': 'LIMIT_BAL', 'X2': 'SEX', 'X3': 'EDUCATION', 'X4': 'MARRIAGE', 'X5': 'AGE', 'X6': 'PAY_0', 'X7': 'PAY_2','X8': 'PAY_3', 'X9': 'PAY_4', 'X10': 'PAY_5', 'X11': 'PAY_6', 'X12': 'BILL_AMT1', 'X13': 'BILL_AMT2', 'X14': 'BILL_AMT3', 'X15': 'BILL_AMT4', 'X16': 'BILL_AMT5', 'X17': 'BILL_AMT6', 'X18': 'PAY_AMT1', 'X19': 'PAY_AMT2', 'X20': 'PAY_AMT3', 'X21': 'PAY_AMT4', 'X22': 'PAY_AMT5', 'X23': 'PAY_AMT6'}, inplace=True)

# %%
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  Y
# 0         0         0         0  1
# 1      1000         0      2000  1
# 2      1000      1000      5000  0
# 3      1100      1069      1000  0
# 4      9000       689       679  0
#
# [5 rows x 25 columns]

# %%
data.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  Y
# 29995      5003      3047      5000      1000  0
# 29996      8998       129         0         0  0
# 29997     22000      4200      2000      3100  1
# 29998      1178      1926     52964      1804  1
# 29999      1430      1000      1000      1000  1
#
# [5 rows x 25 columns]

# %%
 #Counting the number of rows:
 print("The number of rows is:", len(data.index))
# Out:
# The number of rows is: 30000

# %%
data.shape
# Out:
# (30000, 25)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         30000 non-null  int64
#  1   LIMIT_BAL  30000 non-null  int64
#  2   SEX        30000 non-null  int64
#  3   EDUCATION  30000 non-null  int64
#  4   MARRIAGE   30000 non-null  int64
#  5   AGE        30000 non-null  int64
#  6   PAY_0      30000 non-null  int64
#  7   PAY_2      30000 non-null  int64
#  8   PAY_3      30000 non-null  int64
#  9   PAY_4      30000 non-null  int64
#  10  PAY_5      30000 non-null  int64
#  11  PAY_6      30000 non-null  int64
#  12  BILL_AMT1  30000 non-null  int64
#  13  BILL_AMT2  30000 non-null  int64
#  14  BILL_AMT3  30000 non-null  int64
#  15  BILL_AMT4  30000 non-null  int64
#  16  BILL_AMT5  30000 non-null  int64
#  17  BILL_AMT6  30000 non-null  int64
#  18  PAY_AMT1   30000 non-null  int64
#  19  PAY_AMT2   30000 non-null  int64
#  20  PAY_AMT3   30000 non-null  int64
#  21  PAY_AMT4   30000 non-null  int64
#  22  PAY_AMT5   30000 non-null  int64
#  23  PAY_AMT6   30000 non-null  int64
#  24  Y          30000 non-null  int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
#Checking the data types of the attributes:
data.dtypes
# Out:
# ID           int64
# LIMIT_BAL    int64
# SEX          int64
# EDUCATION    int64
# MARRIAGE     int64
# AGE          int64
# PAY_0        int64
# PAY_2        int64
# PAY_3        int64
# PAY_4        int64
# PAY_5        int64
# PAY_6        int64
# BILL_AMT1    int64
# BILL_AMT2    int64
# BILL_AMT3    int64
# BILL_AMT4    int64
# BILL_AMT5    int64
# BILL_AMT6    int64
# PAY_AMT1     int64
# PAY_AMT2     int64
# PAY_AMT3     int64
# PAY_AMT4     int64
# PAY_AMT5     int64
# PAY_AMT6     int64
# Y            int64
# dtype: object

# %%
#Checking missing values:
data.isnull().sum()
# Out:
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_0        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# Y            0
# dtype: int64

# %%
#Identifying duplicate records:
duplicates = data[data.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [ID, LIMIT_BAL, SEX, EDUCATION, MARRIAGE, AGE, PAY_0, PAY_2, PAY_3, PAY_4, PAY_5, PAY_6, BILL_AMT1, BILL_AMT2, BILL_AMT3, BILL_AMT4, BILL_AMT5, BILL_AMT6, PAY_AMT1, PAY_AMT2, PAY_AMT3, PAY_AMT4, PAY_AMT5, PAY_AMT6, Y]
# Index: []
#
# [0 rows x 25 columns]

# %%
data.nunique()
# Out:
# ID           30000
# LIMIT_BAL       81
# SEX              2
# EDUCATION        7
# MARRIAGE         4
# AGE             56
# PAY_0           11
# PAY_2           11
# PAY_3           11
# PAY_4           11
# PAY_5           10
# PAY_6           10
# BILL_AMT1    22723
# BILL_AMT2    22346
# BILL_AMT3    22026
# BILL_AMT4    21548
# BILL_AMT5    21010
# BILL_AMT6    20604
# PAY_AMT1      7943
# PAY_AMT2      7899
# PAY_AMT3      7518
# PAY_AMT4      6937
# PAY_AMT5      6897
# PAY_AMT6      6939
# Y                2
# dtype: int64

# %%
# Replacing education values = 0, 5 and 6 with 4, since 0, 5 and 6 are not defined

fill = (data.EDUCATION == 0) | (data.EDUCATION == 5) | (data.EDUCATION == 6)
data.loc[fill, 'EDUCATION'] = 4

print('EDUCATION ' + str(sorted(data['EDUCATION'].unique())))
# Out:
# EDUCATION [1, 2, 3, 4]

# %%
# Replacing marital status value = 0 to 3, since 0 is not defined

fill = (data.MARRIAGE == 0)
data.loc[fill, 'MARRIAGE'] = 3

print('MARRIAGE ' + str(sorted(data['MARRIAGE'].unique())))
# Out:
# MARRIAGE [1, 2, 3]

# %%
data['BillSum'] = data['BILL_AMT1'] + data['BILL_AMT2'] + data['BILL_AMT3'] + data['BILL_AMT4']+ data['BILL_AMT5']+ data['BILL_AMT6']
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0  ...          0          0         0       689         0         0
# 1  ...       3455       3261         0      1000      1000      1000
# 2  ...      14948      15549      1518      1500      1000      1000
# 3  ...      28959      29547      2000      2019      1200      1100
# 4  ...      19146      19131      2000     36681     10000      9000
#
#    PAY_AMT5  PAY_AMT6  Y  BillSum
# 0         0         0  1     7704
# 1         0      2000  1    17077
# 2      1000      5000  0   101653
# 3      1069      1000  0   231334
# 4       689       679  0   109339
#
# [5 rows x 26 columns]

# %%
data['PaySum'] = data['PAY_AMT1'] + data['PAY_AMT2'] + data['PAY_AMT3'] + data['PAY_AMT4']+ data['PAY_AMT5']+ data['PAY_AMT6']
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0  ...          0         0       689         0         0         0         0
# 1  ...       3261         0      1000      1000      1000         0      2000
# 2  ...      15549      1518      1500      1000      1000      1000      5000
# 3  ...      29547      2000      2019      1200      1100      1069      1000
# 4  ...      19131      2000     36681     10000      9000       689       679
#
#    Y  BillSum  PaySum
# 0  1     7704     689
# 1  1    17077    5000
# 2  0   101653   11018
# 3  0   231334    8388
# 4  0   109339   59049
#
# [5 rows x 27 columns]

# %%
data['BillAverage'] = data[['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']].mean(axis=1).round()
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  Y  \
# 0  ...         0       689         0         0         0         0  1
# 1  ...         0      1000      1000      1000         0      2000  1
# 2  ...      1518      1500      1000      1000      1000      5000  0
# 3  ...      2000      2019      1200      1100      1069      1000  0
# 4  ...      2000     36681     10000      9000       689       679  0
#
#    BillSum  PaySum  BillAverage
# 0     7704     689       1284.0
# 1    17077    5000       2846.0
# 2   101653   11018      16942.0
# 3   231334    8388      38556.0
# 4   109339   59049      18223.0
#
# [5 rows x 28 columns]

# %%
data['PayAverage'] = data[['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']].mean(axis=1).round()
data.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  Y  BillSum  PaySum  \
# 0  ...       689         0         0         0         0  1     7704     689
# 1  ...      1000      1000      1000         0      2000  1    17077    5000
# 2  ...      1500      1000      1000      1000      5000  0   101653   11018
# 3  ...      2019      1200      1100      1069      1000  0   231334    8388
# 4  ...     36681     10000      9000       689       679  0   109339   59049
#
#    BillAverage  PayAverage
# 0       1284.0       115.0
# 1       2846.0       833.0
# 2      16942.0      1836.0
# 3      38556.0      1398.0
# 4      18223.0      9842.0
#
# [5 rows x 29 columns]

# %%
# Getting the summary statistics
print("Summary Statistics:")
data.describe().transpose()
# Out:
# Summary Statistics:
#                count           mean            std       min       25%  \
# ID           30000.0   15000.500000    8660.398374       1.0   7500.75
# LIMIT_BAL    30000.0  167484.322667  129747.661567   10000.0  50000.00
# SEX          30000.0       1.603733       0.489129       1.0      1.00
# EDUCATION    30000.0       1.842267       0.744494       1.0      1.00
# MARRIAGE     30000.0       1.557267       0.521405       1.0      1.00
# AGE          30000.0      35.485500       9.217904      21.0     28.00
# PAY_0        30000.0      -0.016700       1.123802      -2.0     -1.00
# PAY_2        30000.0      -0.133767       1.197186      -2.0     -1.00
# PAY_3        30000.0      -0.166200       1.196868      -2.0     -1.00
# PAY_4        30000.0      -0.220667       1.169139      -2.0     -1.00
# PAY_5        30000.0      -0.266200       1.133187      -2.0     -1.00
# PAY_6        30000.0      -0.291100       1.149988      -2.0     -1.00
# BILL_AMT1    30000.0   51223.330900   73635.860576 -165580.0   3558.75
# BILL_AMT2    30000.0   49179.075167   71173.768783  -69777.0   2984.75
# BILL_AMT3    30000.0   47013.154800   69349.387427 -157264.0   2666.25
# BILL_AMT4    30000.0   43262.948967   64332.856134 -170000.0   2326.75
# BILL_AMT5    30000.0   40311.400967   60797.155770  -81334.0   1763.00
# BILL_AMT6    30000.0   38871.760400   59554.107537 -339603.0   1256.00
# PAY_AMT1     30000.0    5663.580500   16563.280354       0.0   1000.00
# PAY_AMT2     30000.0    5921.163500   23040.870402       0.0    833.00
# PAY_AMT3     30000.0    5225.681500   17606.961470       0.0    390.00
# PAY_AMT4     30000.0    4826.076867   15666.159744       0.0    296.00
# PAY_AMT5     30000.0    4799.387633   15278.305679       0.0    252.50
# PAY_AMT6     30000.0    5215.502567   17777.465775       0.0    117.75
# Y            30000.0       0.221200       0.415062       0.0      0.00
# BillSum      30000.0  269861.671200  379564.331162 -336259.0  28688.00
# PaySum       30000.0   31651.392567   60827.677939       0.0   6679.75
# BillAverage  30000.0   44976.943700   63260.722001  -56043.0   4781.75
# PayAverage   30000.0    5275.231633   10137.946665       0.0   1113.00
#
#                   50%        75%        max
# ID            15000.5   22500.25    30000.0
# LIMIT_BAL    140000.0  240000.00  1000000.0
# SEX               2.0       2.00        2.0
# EDUCATION         2.0       2.00        4.0
# MARRIAGE          2.0       2.00        3.0
# AGE              34.0      41.00       79.0
# PAY_0             0.0       0.00        8.0
# PAY_2             0.0       0.00        8.0
# PAY_3             0.0       0.00        8.0
# PAY_4             0.0       0.00        8.0
# PAY_5             0.0       0.00        8.0
# PAY_6             0.0       0.00        8.0
# BILL_AMT1     22381.5   67091.00   964511.0
# BILL_AMT2     21200.0   64006.25   983931.0
# BILL_AMT3     20088.5   60164.75  1664089.0
# BILL_AMT4     19052.0   54506.00   891586.0
# BILL_AMT5     18104.5   50190.50   927171.0
# BILL_AMT6     17071.0   49198.25   961664.0
# PAY_AMT1       2100.0    5006.00   873552.0
# PAY_AMT2       2009.0    5000.00  1684259.0
# PAY_AMT3       1800.0    4505.00   896040.0
# PAY_AMT4       1500.0    4013.25   621000.0
# PAY_AMT5       1500.0    4031.50   426529.0
# PAY_AMT6       1500.0    4000.00   528666.0
# Y                 0.0       0.00        1.0
# BillSum      126311.0  342626.50  5263883.0
# PaySum        14383.0   33503.50  3764066.0
# BillAverage   21052.0   57104.25   877314.0
# PayAverage     2397.5    5584.00   627344.0

# %%
categorical_variables = ['SEX', 'EDUCATION', 'MARRIAGE']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Count plot for Sex
sns.countplot(x='SEX', data=data)
plt.title('Count Plot of gender')
plt.show()

# Bar plot for Sex and PayAverage
sns.barplot(x='SEX', y='PayAverage', data=data)
plt.show()

# %%
sex = sns.countplot(x='SEX', hue='Y', data=data)
sex.set_xticklabels(['Male','Female'])
plt.show()
# Out:
# <ipython-input-173-19636eb255d9>:2: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
# Count plot for education level
sns.countplot(x='EDUCATION', data=data)
plt.title('Count Plot of Education Level')
plt.show()

# Bar plot for Education Leval and PayAverage
sns.barplot(x='EDUCATION', y='PayAverage', data=data)
plt.show()

# %%
education = sns.countplot(x='EDUCATION', hue='Y', data=data)
education.set_xticklabels(['Graduate School','University','High School','Other'])
plt.show()
# Out:
# <ipython-input-175-34c8c53186c9>:2: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
# Count plot for marital status
sns.countplot(x='MARRIAGE', data=data)
plt.title('Count Plot of Marital Status')
plt.show()

# Bar plot for Education Leval and PayAverage
sns.barplot(x='MARRIAGE', y='PayAverage', data=data)
plt.show()

# %%
marriage = sns.countplot(x='MARRIAGE', hue='Y', data=data)
marriage.set_xticklabels(['Married','Single', 'Other'])
plt.show()
# Out:
# <ipython-input-177-b468166dd36f>:2: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
data[categorical_variables].plot(kind='box')
plt.title('Boxplot for categorical variables')
plt.show()

# %%
# Count plot for target variable:
sns.countplot(x='Y', data=data)
plt.title('Count Plot of Default Payment Next Month')
plt.show()

# %%
data['Y'].value_counts(normalize=True) * 100
# Imbalanced dataset where class '1' (default payment = Yes) significantly outnumbers
# class '0' (default payment = No).
# Out:
# Y
# 0    77.88
# 1    22.12
# Name: proportion, dtype: float64

# %%
#Calculating and printing the Pearson correlation matrix
print("Pearson Correlation Matrix:")
pearson_correlation_matrix_all = data.corr().round(2)
pearson_correlation_matrix_all
# Out:
# Pearson Correlation Matrix:
#                ID  LIMIT_BAL   SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  \
# ID           1.00       0.03  0.02       0.04     -0.03  0.02  -0.03  -0.01
# LIMIT_BAL    0.03       1.00  0.02      -0.23     -0.11  0.14  -0.27  -0.30
# SEX          0.02       0.02  1.00       0.01     -0.03 -0.09  -0.06  -0.07
# EDUCATION    0.04      -0.23  0.01       1.00     -0.14  0.18   0.11   0.13
# MARRIAGE    -0.03      -0.11 -0.03      -0.14      1.00 -0.41   0.02   0.02
# AGE          0.02       0.14 -0.09       0.18     -0.41  1.00  -0.04  -0.05
# PAY_0       -0.03      -0.27 -0.06       0.11      0.02 -0.04   1.00   0.67
# PAY_2       -0.01      -0.30 -0.07       0.13      0.02 -0.05   0.67   1.00
# PAY_3       -0.02      -0.29 -0.07       0.12      0.03 -0.05   0.57   0.77
# PAY_4       -0.00      -0.27 -0.06       0.12      0.03 -0.05   0.54   0.66
# PAY_5       -0.02      -0.25 -0.06       0.10      0.03 -0.05   0.51   0.62
# PAY_6       -0.02      -0.24 -0.04       0.09      0.03 -0.05   0.47   0.58
# BILL_AMT1    0.02       0.29 -0.03       0.02     -0.03  0.06   0.19   0.23
# BILL_AMT2    0.02       0.28 -0.03       0.01     -0.03  0.05   0.19   0.24
# BILL_AMT3    0.02       0.28 -0.02       0.01     -0.03  0.05   0.18   0.22
# BILL_AMT4    0.04       0.29 -0.02      -0.01     -0.03  0.05   0.18   0.22
# BILL_AMT5    0.02       0.30 -0.02      -0.01     -0.03  0.05   0.18   0.22
# BILL_AMT6    0.02       0.29 -0.02      -0.01     -0.03  0.05   0.18   0.22
# PAY_AMT1     0.01       0.20 -0.00      -0.04     -0.00  0.03  -0.08  -0.08
# PAY_AMT2     0.01       0.18 -0.00      -0.03     -0.01  0.02  -0.07  -0.06
# PAY_AMT3     0.04       0.21 -0.01      -0.04     -0.00  0.03  -0.07  -0.06
# PAY_AMT4     0.01       0.20 -0.00      -0.04     -0.01  0.02  -0.06  -0.05
# PAY_AMT5     0.00       0.22 -0.00      -0.05     -0.00  0.02  -0.06  -0.04
# PAY_AMT6     0.00       0.22 -0.00      -0.04     -0.01  0.02  -0.06  -0.04
# Y           -0.01      -0.15 -0.04       0.03     -0.03  0.01   0.32   0.26
# BillSum      0.02       0.30 -0.03       0.00     -0.03  0.05   0.19   0.24
# PaySum       0.02       0.35 -0.00      -0.07     -0.01  0.04  -0.12  -0.09
# BillAverage  0.02       0.30 -0.03       0.00     -0.03  0.05   0.19   0.24
# PayAverage   0.02       0.35 -0.00      -0.07     -0.01  0.04  -0.12  -0.09
#
#              PAY_3  PAY_4  ...  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# ID           -0.02  -0.00  ...      0.01      0.04      0.01      0.00
# LIMIT_BAL    -0.29  -0.27  ...      0.18      0.21      0.20      0.22
# SEX          -0.07  -0.06  ...     -0.00     -0.01     -0.00     -0.00
# EDUCATION     0.12   0.12  ...     -0.03     -0.04     -0.04     -0.05
# MARRIAGE      0.03   0.03  ...     -0.01     -0.00     -0.01     -0.00
# AGE          -0.05  -0.05  ...      0.02      0.03      0.02      0.02
# PAY_0         0.57   0.54  ...     -0.07     -0.07     -0.06     -0.06
# PAY_2         0.77   0.66  ...     -0.06     -0.06     -0.05     -0.04
# PAY_3         1.00   0.78  ...     -0.07     -0.05     -0.05     -0.04
# PAY_4         0.78   1.00  ...     -0.00     -0.07     -0.04     -0.03
# PAY_5         0.69   0.82  ...     -0.00      0.01     -0.06     -0.03
# PAY_6         0.63   0.72  ...     -0.01      0.01      0.02     -0.05
# BILL_AMT1     0.21   0.20  ...      0.10      0.16      0.16      0.17
# BILL_AMT2     0.24   0.23  ...      0.10      0.15      0.15      0.16
# BILL_AMT3     0.23   0.24  ...      0.32      0.13      0.14      0.18
# BILL_AMT4     0.23   0.25  ...      0.21      0.30      0.13      0.16
# BILL_AMT5     0.23   0.24  ...      0.18      0.25      0.29      0.14
# BILL_AMT6     0.22   0.24  ...      0.17      0.23      0.25      0.31
# PAY_AMT1      0.00  -0.01  ...      0.29      0.25      0.20      0.15
# PAY_AMT2     -0.07  -0.00  ...      1.00      0.24      0.18      0.18
# PAY_AMT3     -0.05  -0.07  ...      0.24      1.00      0.22      0.16
# PAY_AMT4     -0.05  -0.04  ...      0.18      0.22      1.00      0.15
# PAY_AMT5     -0.04  -0.03  ...      0.18      0.16      0.15      1.00
# PAY_AMT6     -0.04  -0.03  ...      0.16      0.16      0.16      0.15
# Y             0.24   0.22  ...     -0.06     -0.06     -0.06     -0.06
# BillSum       0.24   0.24  ...      0.19      0.21      0.19      0.19
# PaySum       -0.07  -0.05  ...      0.67      0.59      0.53      0.49
# BillAverage   0.24   0.24  ...      0.19      0.21      0.19      0.19
# PayAverage   -0.07  -0.05  ...      0.67      0.59      0.53      0.49
#
#              PAY_AMT6     Y  BillSum  PaySum  BillAverage  PayAverage
# ID               0.00 -0.01     0.02    0.02         0.02        0.02
# LIMIT_BAL        0.22 -0.15     0.30    0.35         0.30        0.35
# SEX             -0.00 -0.04    -0.03   -0.00        -0.03       -0.00
# EDUCATION       -0.04  0.03     0.00   -0.07         0.00       -0.07
# MARRIAGE        -0.01 -0.03    -0.03   -0.01        -0.03       -0.01
# AGE              0.02  0.01     0.05    0.04         0.05        0.04
# PAY_0           -0.06  0.32     0.19   -0.12         0.19       -0.12
# PAY_2           -0.04  0.26     0.24   -0.09         0.24       -0.09
# PAY_3           -0.04  0.24     0.24   -0.07         0.24       -0.07
# PAY_4           -0.03  0.22     0.24   -0.05         0.24       -0.05
# PAY_5           -0.02  0.20     0.26   -0.03         0.26       -0.03
# PAY_6           -0.03  0.19     0.26   -0.01         0.26       -0.01
# BILL_AMT1        0.18 -0.02     0.94    0.26         0.94        0.26
# BILL_AMT2        0.17 -0.01     0.96    0.29         0.96        0.29
# BILL_AMT3        0.18 -0.01     0.96    0.36         0.96        0.36
# BILL_AMT4        0.18 -0.01     0.96    0.35         0.96        0.35
# BILL_AMT5        0.16 -0.01     0.95    0.36         0.95        0.36
# BILL_AMT6        0.12 -0.01     0.93    0.36         0.93        0.36
# PAY_AMT1         0.19 -0.07     0.23    0.60         0.23        0.60
# PAY_AMT2         0.16 -0.06     0.19    0.67         0.19        0.67
# PAY_AMT3         0.16 -0.06     0.21    0.59         0.21        0.59
# PAY_AMT4         0.16 -0.06     0.19    0.53         0.19        0.53
# PAY_AMT5         0.15 -0.06     0.19    0.49         0.19        0.49
# PAY_AMT6         1.00 -0.05     0.18    0.53         0.18        0.53
# Y               -0.05  1.00    -0.01   -0.10        -0.01       -0.10
# BillSum          0.18 -0.01     1.00    0.34         1.00        0.34
# PaySum           0.53 -0.10     0.34    1.00         0.34        1.00
# BillAverage      0.18 -0.01     1.00    0.34         1.00        0.34
# PayAverage       0.53 -0.10     0.34    1.00         0.34        1.00
#
# [29 rows x 29 columns]

# %%
numeric_variables = ['LIMIT_BAL', 'AGE', 'PAY_0','PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BillAverage', 'PayAverage']

#Calculating and printing the Pearson correlation matrix
print("Pearson Correlation Matrix of numeric variables:")
pearson_correlation_matrix = data[numeric_variables].corr().round(2)
pearson_correlation_matrix
# Out:
# Pearson Correlation Matrix of numeric variables:
#              LIMIT_BAL   AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  \
# LIMIT_BAL         1.00  0.14  -0.27  -0.30  -0.29  -0.27  -0.25  -0.24
# AGE               0.14  1.00  -0.04  -0.05  -0.05  -0.05  -0.05  -0.05
# PAY_0            -0.27 -0.04   1.00   0.67   0.57   0.54   0.51   0.47
# PAY_2            -0.30 -0.05   0.67   1.00   0.77   0.66   0.62   0.58
# PAY_3            -0.29 -0.05   0.57   0.77   1.00   0.78   0.69   0.63
# PAY_4            -0.27 -0.05   0.54   0.66   0.78   1.00   0.82   0.72
# PAY_5            -0.25 -0.05   0.51   0.62   0.69   0.82   1.00   0.82
# PAY_6            -0.24 -0.05   0.47   0.58   0.63   0.72   0.82   1.00
# BillAverage       0.30  0.05   0.19   0.24   0.24   0.24   0.26   0.26
# PayAverage        0.35  0.04  -0.12  -0.09  -0.07  -0.05  -0.03  -0.01
#
#              BillAverage  PayAverage
# LIMIT_BAL           0.30        0.35
# AGE                 0.05        0.04
# PAY_0               0.19       -0.12
# PAY_2               0.24       -0.09
# PAY_3               0.24       -0.07
# PAY_4               0.24       -0.05
# PAY_5               0.26       -0.03
# PAY_6               0.26       -0.01
# BillAverage         1.00        0.34
# PayAverage          0.34        1.00

# %%
# Printing summary statistics of numeric variables
print("\nSummary Statistics of numeric variables:")
data[numeric_variables].describe().transpose()
# Out:
# Summary Statistics of numeric variables:
#                count           mean            std      min       25%  \
# LIMIT_BAL    30000.0  167484.322667  129747.661567  10000.0  50000.00
# AGE          30000.0      35.485500       9.217904     21.0     28.00
# PAY_0        30000.0      -0.016700       1.123802     -2.0     -1.00
# PAY_2        30000.0      -0.133767       1.197186     -2.0     -1.00
# PAY_3        30000.0      -0.166200       1.196868     -2.0     -1.00
# PAY_4        30000.0      -0.220667       1.169139     -2.0     -1.00
# PAY_5        30000.0      -0.266200       1.133187     -2.0     -1.00
# PAY_6        30000.0      -0.291100       1.149988     -2.0     -1.00
# BillAverage  30000.0   44976.943700   63260.722001 -56043.0   4781.75
# PayAverage   30000.0    5275.231633   10137.946665      0.0   1113.00
#
#                   50%        75%        max
# LIMIT_BAL    140000.0  240000.00  1000000.0
# AGE              34.0      41.00       79.0
# PAY_0             0.0       0.00        8.0
# PAY_2             0.0       0.00        8.0
# PAY_3             0.0       0.00        8.0
# PAY_4             0.0       0.00        8.0
# PAY_5             0.0       0.00        8.0
# PAY_6             0.0       0.00        8.0
# BillAverage   21052.0   57104.25   877314.0
# PayAverage     2397.5    5584.00   627344.0

# %%
import matplotlib.pyplot as plt

sns.pairplot(data[numeric_variables])
plt.show()

# %%
data['LIMIT_BAL'].plot(kind='box')
plt.title('Boxplot for Limit Balance')
plt.show()

# %%
data['AGE'].plot(kind='box')
plt.title('Boxplot for Age')
plt.show()

# %%
repayment_variables = ['PAY_0','PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
data[repayment_variables].plot(kind='box')
plt.title('Boxplot for Repayment Status')
plt.show()

# %%
data['BillAverage'].plot(kind='box')
plt.title('Boxplot for BillAverage')
plt.show()

# %%
data['PayAverage'].plot(kind='box')
plt.title('Boxplot for PayAverage')
plt.show()

# %%
#Normalizing the numeric attributes
from sklearn.preprocessing import MinMaxScaler

# Initializing the scaler
scaler = MinMaxScaler()
# Fitting and transforming the data
X = scaler.fit_transform(data[numeric_variables])

# %%
# Validating minimum and maximum values are set as 0.00 and 1.00 respectively
normalized_df_summary = pd.DataFrame(X).describe()
normalized_df_summary
# Out:
#                   0             1            2             3             4  \
# count  30000.000000  30000.000000  30000.00000  30000.000000  30000.000000
# mean       0.159075      0.249750      0.19833      0.186623      0.183380
# std        0.131058      0.158929      0.11238      0.119719      0.119687
# min        0.000000      0.000000      0.00000      0.000000      0.000000
# 25%        0.040404      0.120690      0.10000      0.100000      0.100000
# 50%        0.131313      0.224138      0.20000      0.200000      0.200000
# 75%        0.232323      0.344828      0.20000      0.200000      0.200000
# max        1.000000      1.000000      1.00000      1.000000      1.000000
#
#                   5             6             7             8             9
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean       0.177933      0.173380      0.170890      0.108233      0.008409
# std        0.116914      0.113319      0.114999      0.067778      0.016160
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.100000      0.100000      0.100000      0.065168      0.001774
# 50%        0.200000      0.200000      0.200000      0.082600      0.003822
# 75%        0.200000      0.200000      0.200000      0.121226      0.008901
# max        1.000000      1.000000      1.000000      1.000000      1.000000

# %%
import numpy as np
age = sns.countplot(x='AGE', hue='Y', data=data)
age.set_title('Age by Default Payment')
plt.xticks(np.arange(0, 90, step=10))
plt.show()

# %%
pay0 = sns.countplot(x="PAY_0", hue='Y', data=data)
pay0.set_xticklabels(['No Consumption','Pay Duly','Revolving Credit','Delay 1 mth','Delay 2 mths','Delay 3 mths','Delay 4 mths','Delay 5 mths','Delay 6 mths','Delay 7 mths','Delay 8 mths'])
pay0.set_title('History of Past Payment (most recent month)')
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-196-ddfd239ade31>:2: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.

# %%
import plotly.express as px
billaverage = px.histogram(data, x='BillAverage', nbins=100, color='Y', range_x=[-15000, 350000])
billaverage.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1071af46-e60a-4555-bb06-e8318b98be7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1071af46-e60a-4555-bb06-e8318b98be7b")) {                    Plotly.newPlot(                        "1071af46-e60a-4555-bb06-e8318b98be7b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Y=1\u003cbr\u003eBillAverage=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1